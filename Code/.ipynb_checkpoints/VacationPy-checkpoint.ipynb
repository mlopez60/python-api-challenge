# %% [markdown]
# # VacationPy

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data\cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp (F)  Humidity  \
# 0        0        yellowknife  62.4560 -114.3525         10.42        98
# 1        1          grytviken -54.2811  -36.5092         43.11        80
# 2        2  port-aux-francais -49.3500   70.2167         41.02        68
# 3        3         walvis bay -22.9575   14.5053         67.08        79
# 4        4       longyearbyen  78.2186   15.6401         13.84        79
#
#    Cloudiness  Wind Speed Country        Date
# 0          96        3.62      CA  1706476091
# 1          16       17.65      GS  1706476091
# 2          87       29.97      TF  1706475534
# 3         100        7.58     NaN  1706475674
# 4           0        6.91      SJ  1706476092

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map1=city_data_df.hvplot.points("Lng", "Lat", geo = True, tiles = "EsriImagery", size = "Humidity", color = "City")

# Display the map
map1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrowcity= city_data_df.loc[(city_data_df["Max Temp (F)"] > 80)& (city_data_df["Humidity"]<50)]

# Drop any rows with null values
narrowcity= narrowcity.dropna()

# Display sample data
narrowcity
# Out:
#      City_ID                           City      Lat       Lng  Max Temp (F)  \
# 46        46                    sao vicente -23.9631  -46.3919         84.38
# 103      103                         lodwar   3.1191   35.5973         87.80
# 150      150                         viedma -40.8135  -62.9967         92.46
# 172      172                 ixtlan del rio  21.0333 -104.3667         90.34
# 184      184  ingeniero guillermo n. juarez -23.9000  -61.8500         99.70
# 238      238          coahuayana de hidalgo  18.7000 -103.6583         88.63
# 249      249            san luis de la loma  17.2706 -100.8939         87.26
# 260      260                         lompoc  34.6391 -120.4579         80.78
# 303      303                        kouango   4.9934   19.9619         80.58
# 308      308                        lagunas  -5.2269  -75.6753         93.85
# 358      358                  bahia de kino  28.8333 -111.9333         80.53
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrowcity[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df.insert(5, "Hotel Name", '')

# Display sample data
hotel_df
# Out:
#                               City Country      Lat       Lng  Humidity  \
# 46                     sao vicente      BR -23.9631  -46.3919        47
# 103                         lodwar      KE   3.1191   35.5973        37
# 150                         viedma      AR -40.8135  -62.9967        20
# 172                 ixtlan del rio      MX  21.0333 -104.3667        13
# 184  ingeniero guillermo n. juarez      AR -23.9000  -61.8500        18
# 238          coahuayana de hidalgo      MX  18.7000 -103.6583        47
# 249            san luis de la loma      MX  17.2706 -100.8939        45
# 260                         lompoc      US  34.6391 -120.4579        32
# 303                        kouango      CF   4.9934   19.9619        27
# 308                        lagunas      PE  -5.2269  -75.6753        42
# 358                  bahia de kino      MX  28.8333 -111.9333        46
# 377                         obubra      NG   6.0752    8.3290        24
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"apiKey":geoapify_key, "format": "json", "categories": "accommodation"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# sao vicente - nearest hotel: Pousada Vitória
# lodwar - nearest hotel: Africana silent lodge
# viedma - nearest hotel: Níjar
# ixtlan del rio - nearest hotel: El marques de Minas
# ingeniero guillermo n. juarez - nearest hotel: Hotel Carfa
# coahuayana de hidalgo - nearest hotel: No hotel found
# san luis de la loma - nearest hotel: No hotel found
# lompoc - nearest hotel: Alano Club
# kouango - nearest hotel: No hotel found
# lagunas - nearest hotel: Hospedaje Eco
# bahia de kino - nearest hotel: Hotel Hacienda
# obubra - nearest hotel: No hotel found
# general conesa - nearest hotel: Gran Hotel Conesa
# general pico - nearest hotel: Euskadi Hotel
# rakops - nearest hotel: Rakops River Lodge
# tinogasta - nearest hotel: hostal Las Parinas
# poxoreo - nearest hotel: No hotel found
# wajir - nearest hotel: Jamal Plaza
# el porvenir - nearest hotel: No hotel found
#                               City Country      Lat       Lng  Humidity  \
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map2 = hotel_df.hvplot.points("Lng", "Lat", geo = True, tiles = "EsriImagery", size = "Humidity", color = "City", hover_cols =["Hotel Name", "Country"])

# Display the map
map2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
